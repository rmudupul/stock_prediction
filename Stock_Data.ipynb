# %%
import pandas as pd
import numpy as np
import yfinance as yf
import os, contextlib

# %%
# Function to calculate simple and log returns
def calculate_returns(data):
    # Simple returns
    data['Simple Return'] = data['Adj Close'].pct_change()
    
    # Logarithmic returns
    data['Log Return'] = np.log(data['Adj Close'] / data['Adj Close'].shift(1))
    
    return data

# Function to calculate historical volatility, adjusted for the timeframe
def calculate_volatility(data, timeframe):
    # Set the appropriate number of periods in a year depending on the timeframe
    periods_in_year = {
        'daily': 252,     # 252 trading days in a year
        'weekly': 52,     # 52 weeks in a year
        'monthly': 12,    # 12 months in a year
        '3mo': 4,         # 4 quarters in a year (3-month periods)
        '6mo': 2,         # 2 half-year periods in a year
        '1y': 1,          # 1 year
        '5y': 1/5         # 1 year spans 5 years (inverse)
    }
    
    # Default window size for rolling volatility is set to 21 periods (can be adjusted if needed)
    window_size = 21

    # Use the number of periods per year specific to the timeframe
    annualization_factor = np.sqrt(periods_in_year[timeframe])

    # Calculate daily (or respective timeframe) volatility and annualize it
    data['Volatility'] = data['Log Return'].rolling(window=window_size).std() * annualization_factor

    return data

# %%
timeframes = {
    'daily': '1d',
    'weekly': '1wk',
    'monthly': '1mo',
    '3mo': '3mo',
    '6mo': '6mo',
    '1y': '1y',
    '5y': '5y'
}

# Ensure the 'hist' directory exists
output_dir = 'hist'
os.makedirs(output_dir, exist_ok=True)

# Load the list of symbols and clean data
data = pd.read_csv("http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt", sep='|')
data_clean = data[data['Test Issue'] == 'N']
symbols = data_clean['NASDAQ Symbol'].tolist()

# Adjust the limit and range
limit = limit if limit else len(symbols)
end = min(offset + limit, len(symbols))
is_valid = [False] * len(symbols)

# %%
# Function to calculate SMAs
def calculate_sma(data, timeframes):
    for period in timeframes:
        data[f'SMA_{period}'] = data['Adj Close'].rolling(window=period).mean()
    return data

# Function to calculate EMAs
def calculate_ema(data, timeframes):
    for period in timeframes:
        data[f'EMA_{period}'] = data['Adj Close'].ewm(span=period, adjust=False).mean()
    return data
# Timeframes for different data resolutions
timeframe_sma_ema = {
    'daily': {
        'SMA': [10, 50, 200],
        'EMA': [12, 26, 50]
    },
    'weekly': {
        'SMA': [4, 13, 52],
        'EMA': [9, 26, 52]
    },
    'monthly': {
        'SMA': [3, 12, 24],
        'EMA': [6, 12]
    },
    '3mo': {
        'SMA': [1, 4, 8],
        'EMA': [1, 4, 8]
    },
    '6mo': {
        'SMA': [1, 2, 4],
        'EMA': [1, 2, 4]
    },
    '1y': {
        'SMA': [1, 2, 5],
        'EMA': [1, 2, 5]
    },
    '5y': {
        'SMA': [2, 5, 10],
        'EMA': [2, 5, 10]
    }
}

# %%
# Function to calculate MACD for all timeframes
def calculate_macd(data, short_window=12, long_window=26, signal_window=9):
   
    data['MACD'] = data['Adj Close'].ewm(span=short_window, adjust=False).mean() - data['Adj Close'].ewm(span=long_window, adjust=False).mean()
    data['Signal Line'] = data['MACD'].ewm(span=signal_window, adjust=False).mean()  # Signal line
    data['Histogram'] = data['MACD'] - data['Signal Line']
    return data

# Function to calculate RSI
def calculate_rsi(data, period=14):
    delta = data['Adj Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=period).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=period).mean()
    rs = gain / loss
    data['RSI'] = 100 - (100 / (1 + rs))
    return data

# %%
# Function to calculate Bollinger Bands
def calculate_bollinger_bands(data, window=20, num_std_dev=2):
    data['Middle Band'] = data['Adj Close'].rolling(window=window).mean()
    data['Upper Band'] = data['Middle Band'] + (data['Adj Close'].rolling(window=window).std() * num_std_dev)
    data['Lower Band'] = data['Middle Band'] - (data['Adj Close'].rolling(window=window).std() * num_std_dev)
    return data

# %%
# Force silencing of verbose API output
with open(os.devnull, 'w') as devnull:
    with contextlib.redirect_stdout(devnull):
        for i in range(offset, end):
            s = symbols[i]
            
            # Download data for different timeframes
            for timeframe, period in timeframes.items():
                data = yf.download(s, period='max', interval=period)
                
                # Skip if no data is found
                if data.empty:
                    continue

                # Calculate additional features
                data = calculate_returns(data)
                data = calculate_volatility(data, timeframe)

                # Calculate SMAs and EMAs for this timeframe
                data = calculate_sma(data, timeframe_sma_ema[timeframe]['SMA'])
                data = calculate_ema(data, timeframe_sma_ema[timeframe]['EMA'])

                # Calculate MACD for all timeframes
                data = calculate_macd(data)

                # Calculate RSI for all timeframes (commonly 14 days)
                data = calculate_rsi(data)

                # Calculate Bollinger Bands
                data = calculate_bollinger_bands(data)


                # Save the data for each timeframe
                data.to_csv(f'{output_dir}/{s}_{timeframe}.csv')

                # Save dividends, splits, and other data for the symbol
                stock = yf.Ticker(s)

                # # Save dividends data if available
                # dividends = stock.dividends
                # if not dividends.empty:
                #     dividends.to_csv(f'{output_dir}/{s}_dividends.csv')

                # # Save stock splits data if available
                # splits = stock.splits
                # if not splits.empty:
                #     splits.to_csv(f'{output_dir}/{s}_splits.csv')

                # quarterly_earnings = stock.quarterly_earnings  # Quarterly earnings data
                # if quarterly_earnings is not None and not quarterly_earnings.empty:
                #     quarterly_earnings.to_csv(f'{output_dir}/{s}_quarterly_earnings.csv')

                # financials = stock.financials  # Yearly financials
                # if financials is not None and not financials.empty:
                #     financials.to_csv(f'{output_dir}/{s}_financials.csv')

                # quarterly_financials = stock.quarterly_financials  # Quarterly financials
                # if quarterly_financials is not None and not quarterly_financials.empty:
                #     quarterly_financials.to_csv(f'{output_dir}/{s}_quarterly_financials.csv')

                # recommendations = stock.recommendations  # Analyst recommendations
                # if recommendations is not None and not recommendations.empty:
                #     recommendations.to_csv(f'{output_dir}/{s}_recommendations.csv')

            # Mark the symbol as valid if data was saved
            is_valid[i] = True

print('Total number of valid symbols downloaded = {}'.format(sum(is_valid)))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['A']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['A']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['A']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAAU']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAAU']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAAU']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AADI']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AADI']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AADI']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AADR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AADR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AADR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAL']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAL']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAL']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM=']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM+']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAME']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAME']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAME']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAOI']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAOI']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAOI']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAON']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAON']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAON']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAP']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAP']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAP']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPB']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPB']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPB']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPD']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPD']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPD']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (6mo 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=6mo is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=1y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (5y 1925-11-01 -> 2024-10-07) (Yahoo error = "Invalid input - interval=5y is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 9
#       7 # Download data for different timeframes
#       8 for timeframe, period in timeframes.items():
# ----> 9     data = yf.download(s, period='max', interval=period)
#      11     # Skip if no data is found
#      12     if data.empty:
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/multi.py:152, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session)
#     145         _download_one_threaded(ticker, period=period, interval=interval,
#     146                                start=start, end=end, prepost=prepost,
#     147                                actions=actions, auto_adjust=auto_adjust,
#     148                                back_adjust=back_adjust, repair=repair, keepna=keepna,
#     149                                progress=(progress and i > 0), proxy=proxy,
#     150                                rounding=rounding, timeout=timeout)
#     151     while len(shared._DFS) < len(tickers):
# --> 152         _time.sleep(0.01)
#     153 # download synchronously
#     154 else:
#     155     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:

# %%
print(len(symbols))
# Out:
# 11099

# %%
# Ensure the 'hist' directory exists
output_dir = 'hist'
os.makedirs(output_dir, exist_ok=True)

# Adjusting the limit and range
limit = limit if limit else len(symbols)
end = min(offset + limit, len(symbols))
is_valid = [False] * len(symbols)

# Force silencing of verbose API output
with open(os.devnull, 'w') as devnull:
    with contextlib.redirect_stdout(devnull):
        for i in range(offset, end):
            s = symbols[i]
            # Download historical stock data for the symbol
            data = yf.download(s, period=period)
            
            # Skip if no data is found
            if len(data.index) == 0:
                continue

            # Save stock price data
            data.to_csv(f'{output_dir}/{s}.csv')

            # Fetch additional data for the symbol
            stock = yf.Ticker(s)

            # Save dividends data if available
            dividends = stock.dividends
            if not dividends.empty:
                dividends.to_csv(f'{output_dir}/{s}_dividends.csv')

            # Save stock splits data if available
            splits = stock.splits
            if not splits.empty:
                splits.to_csv(f'{output_dir}/{s}_splits.csv')
                
            quarterly_earnings = stock.quarterly_earnings  # Quarterly earnings data
            if quarterly_earnings is not None and not quarterly_earnings.empty:
                quarterly_earnings.to_csv(f'{output_dir}/{s}_quarterly_earnings.csv')

            # Save financials data (annual and quarterly)
            financials = stock.financials  # Yearly financials
            if financials is not None and not financials.empty:
                financials.to_csv(f'{output_dir}/{s}_financials.csv')

            quarterly_financials = stock.quarterly_financials  # Quarterly financials
            if quarterly_financials is not None and not quarterly_financials.empty:
                quarterly_financials.to_csv(f'{output_dir}/{s}_quarterly_financials.csv')

            # Save analyst recommendations if available
            recommendations = stock.recommendations
            if recommendations is not None and not recommendations.empty:
                recommendations.to_csv(f'{output_dir}/{s}_recommendations.csv')

            is_valid[i] = True  # Mark as valid if all data is successfully saved

print('Total number of valid symbols downloaded = {}'.format(sum(is_valid)))
# Out:
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAA?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AAA&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAAU?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AAAU&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AACT?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AACT&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT=']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=6mo) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACT+']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=6mo) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AADR?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AADR&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM']: YFInvalidPeriodError("%ticker%: Period '6mo' is invalid, must be one of ['1d', '5d', '1mo', 'ytd', 'max']")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM=']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=6mo) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAM+']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=6mo) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAPB?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AAPB&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAPD?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AAPD&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAPR?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AAPR&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAPU?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AAPU&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAPX?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AAPX&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAPY?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AAPY&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAXJ?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=AAXJ&crumb=ekC7geoj.1i
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# [*********************100%***********************]  1 of 1 completed
# /Users/rahul/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 52
#      49     quarterly_financials.to_csv(f'{output_dir}/{s}_quarterly_financials.csv')
#      51 # Save analyst recommendations if available
# ---> 52 recommendations = stock.recommendations
#      53 if recommendations is not None and not recommendations.empty:
#      54     recommendations.to_csv(f'{output_dir}/{s}_recommendations.csv')
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/ticker.py:177, in Ticker.recommendations(self)
#     175 @property
#     176 def recommendations(self):
# --> 177     return self.get_recommendations()
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/base.py:150, in TickerBase.get_recommendations(self, proxy, as_dict)
#     145 """
#     146 Returns a DataFrame with the recommendations
#     147 Columns: period  strongBuy  buy  hold  sell  strongSell
#     148 """
#     149 self._quote.proxy = proxy or self.proxy
# --> 150 data = self._quote.recommendations
#     151 if as_dict:
#     152     return data.to_dict()
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/quote.py:530, in Quote.recommendations(self)
#     527 @property
#     528 def recommendations(self) -> pd.DataFrame:
#     529     if self._recommendations is None:
# --> 530         result = self._fetch(self.proxy, modules=['recommendationTrend'])
#     531         if result is None:
#     532             self._recommendations = pd.DataFrame()
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/scrapers/quote.py:587, in Quote._fetch(self, proxy, modules)
#     585 params_dict = {"modules": modules, "corsDomain": "finance.yahoo.com", "formatted": "false", "symbol": self._symbol}
#     586 try:
# --> 587     result = self._data.get_raw_json(_QUOTE_SUMMARY_URL_ + f"/{self._symbol}", user_agent_headers=self._data.user_agent_headers, params=params_dict, proxy=proxy)
#     588 except requests.exceptions.HTTPError as e:
#     589     utils.get_yf_logger().error(str(e))
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/data.py:398, in YfData.get_raw_json(self, url, user_agent_headers, params, proxy, timeout)
#     396 def get_raw_json(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
#     397     utils.get_yf_logger().debug(f'get_raw_json(): {url}')
# --> 398     response = self.get(url, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
#     399     response.raise_for_status()
#     400     return response.json()
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/data.py:374, in YfData.get(self, url, user_agent_headers, params, proxy, timeout)
#     372 else:
#     373     self._set_cookie_strategy('basic')
# --> 374 cookie, crumb, strategy = self._get_cookie_and_crumb(proxy, timeout)
#     375 request_args['params']['crumb'] = crumb
#     376 if strategy == 'basic':
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/data.py:316, in YfData._get_cookie_and_crumb(self, proxy, timeout)
#     314 with self._cookie_lock:
#     315     if self._cookie_strategy == 'csrf':
# --> 316         crumb = self._get_crumb_csrf()
#     317         if crumb is None:
#     318             # Fail
#     319             self._set_cookie_strategy('basic', have_lock=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/data.py:285, in YfData._get_crumb_csrf(self, proxy, timeout)
#     282     utils.get_yf_logger().debug('reusing crumb')
#     283     return self._crumb
# --> 285 if not self._get_cookie_csrf(proxy, timeout):
#     286     # This cookie stored in session
#     287     return None
#     289 get_args = {
#     290     'url': 'https://query2.finance.yahoo.com/v1/test/getcrumb',
#     291     'headers': self.user_agent_headers,
#     292     'proxies': proxy,
#     293     'timeout': timeout}
#
# File ~/anaconda3/lib/python3.10/site-packages/yfinance/data.py:236, in YfData._get_cookie_csrf(self, proxy, timeout)
#     234     response = self._session.get(**get_args)
#     235 else:
# --> 236     response = self._session.get(**get_args)
#     238 soup = BeautifulSoup(response.content, 'html.parser')
#     239 csrfTokenInput = soup.find('input', attrs={'name': 'csrfToken'})
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:724, in <listcomp>(.0)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Fetch data for Apple (AAPL)
aapl = yf.Ticker("AAPL")

# Directory to save CSV files
output_dir = "aapl_data"
os.makedirs(output_dir, exist_ok=True)

# Helper function to save data to CSV
def save_to_csv(data, filename):
    if isinstance(data, pd.DataFrame) or isinstance(data, pd.Series):
        if not data.empty:
            data.to_csv(f"{output_dir}/{filename}.csv")
    elif isinstance(data, dict):
        pd.DataFrame.from_dict(data, orient='index').to_csv(f"{output_dir}/{filename}.csv")

# Get historical market data (remove timezone from index to avoid errors)
hist = aapl.history(period="1mo")
hist.index = hist.index.tz_localize(None)
save_to_csv(hist, "historical_data")

# Show actions (dividends, splits)
aapl.actions.index = aapl.actions.index.tz_localize(None)
save_to_csv(aapl.actions, "actions")

aapl.dividends.index = aapl.dividends.index.tz_localize(None)
save_to_csv(aapl.dividends, "dividends")

aapl.splits.index = aapl.splits.index.tz_localize(None)
save_to_csv(aapl.splits, "splits")

# Share count data (starting from Jan 2022)
shares = aapl.get_shares_full(start="2022-01-01", end=None)
save_to_csv(shares, "share_count")

# Financials
save_to_csv(aapl.income_stmt, "income_statement")
save_to_csv(aapl.quarterly_income_stmt, "quarterly_income_statement")
save_to_csv(aapl.balance_sheet, "balance_sheet")
save_to_csv(aapl.quarterly_balance_sheet, "quarterly_balance_sheet")
save_to_csv(aapl.cashflow, "cashflow_statement")
save_to_csv(aapl.quarterly_cashflow, "quarterly_cashflow_statement")

# Show holders
save_to_csv(aapl.major_holders, "major_holders")
save_to_csv(aapl.institutional_holders, "institutional_holders")
save_to_csv(aapl.mutualfund_holders, "mutual_fund_holders")

# Insider information
save_to_csv(aapl.insider_transactions, "insider_transactions")
save_to_csv(aapl.insider_purchases, "insider_purchases")
save_to_csv(aapl.insider_roster_holders, "insider_holders")

# Recommendations
save_to_csv(aapl.recommendations, "recommendations")
save_to_csv(aapl.recommendations_summary, "recommendations_summary")
save_to_csv(aapl.upgrades_downgrades, "upgrades_downgrades")

# Analysts data
save_to_csv(aapl.analyst_price_targets, "analyst_price_targets")
save_to_csv(aapl.earnings_estimate, "earnings_estimate")
save_to_csv(aapl.revenue_estimate, "revenue_estimate")
save_to_csv(aapl.earnings_history, "earnings_history")
save_to_csv(aapl.eps_trend, "eps_trend")
save_to_csv(aapl.eps_revisions, "eps_revisions")
save_to_csv(aapl.growth_estimates, "growth_estimates")

# Earnings Dates (remove timezone from index)
earnings_dates = aapl.earnings_dates
earnings_dates.index = earnings_dates.index.tz_localize(None)
save_to_csv(earnings_dates, "earnings_dates")

# Show options expirations
options_exp = pd.DataFrame(aapl.options, columns=["Expiration Dates"])
save_to_csv(options_exp, "option_expirations")

# Show news
news_df = pd.DataFrame(aapl.news)
save_to_csv(news_df, "news")

# Get option chain for a specific expiration date (if available)
if aapl.options:
    expiration_date = aapl.options[0]  # Selecting the first available expiration date
    opt = aapl.option_chain(expiration_date)
    save_to_csv(opt.calls, "option_calls")
    save_to_csv(opt.puts, "option_puts")

print(f"Data saved to {output_dir}/")
# Out:
# Data saved to aapl_data/
